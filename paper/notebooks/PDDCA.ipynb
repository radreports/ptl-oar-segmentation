# %%
import SimpleITK as sitk
import numpy as np, torch, nrrd, pandas as pd
import monai.metrics as met

# %%
data = pd.read_csv('/Users/joemarsilla/Downloads/pred/pddca2/pddca_.csv', index_col=0)

# %%
data.head()
# Out:
#                                                    0  \
# 0  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 1  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 2  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 3  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 4  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
#
#                                                    1
# 0  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 1  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 2  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 3  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...
# 4  /cluster/projects/radiomics/EXTERNAL/PDDCA/052...

# %%
pats = list(data['0'])

# %%
p = [p.split('/')[-2] for p in pats]

# %%
# p = list(set(p))

# %%
from collections import OrderedDict
p = OrderedDict((x, True) for x in p).keys()

# %%
p = list(p)

# %%
p
# Out:
# ['0522c0001',
#  '0522c0002',
#  '0522c0003',
#  '0522c0009',
#  '0522c0013',
#  '0522c0014',
#  '0522c0017',
#  '0522c0057',
#  '0522c0070',
#  '0522c0077',
#  '0522c0079',
#  '0522c0081',
#  '0522c0125',
#  '0522c0132',
#  '0522c0147',
#  '0522c0149',
#  '0522c0159',
#  '0522c0161',
#  '0522c0190',
#  '0522c0195',
#  '0522c0226',
#  '0522c0248',
#  '0522c0251',
#  '0522c0253',
#  '0522c0328',
#  '0522c0329',
#  '0522c0330',
#  '0522c0427',
#  '0522c0433',
#  '0522c0441',
#  '0522c0455',
#  '0522c0457',
#  '0522c0479',
#  '0522c0555',
#  '0522c0576',
#  '0522c0598',
#  '0522c0659',
#  '0522c0661',
#  '0522c0667',
#  '0522c0669',
#  '0522c0708',
#  '0522c0727',
#  '0522c0746',
#  '0522c0788',
#  '0522c0806',
#  '0522c0845',
#  '0522c0857',
#  '0522c0878']

# %%
pddca_classes = ['BrainStem', 'Chiasm', 'Mandible', 'OpticNerve_L', 'OpticNerve_R', 'Parotid_L', 'Parotid_R']
# deep_classes2 = ['Brainstem','Lens_Lt', 'Lens_Rt', 'Mandible', 'Optic_Nerve_Lt', 'Optic_Nerve_Rt', 'Parotid_Lt', 'Parotid_Rt', 'Orbit_Lt', 'Orbit_Rt', 'Spinal_Cord', 'Spinal_Canal']
index_ = [1, 18, 5, 16, 17, 6, 7]
chosen = ['BSTEM','SPCOR','ESOPH','LARYNX','MAND','LPAR','RPAR','LACOU','RACOU','RPLEX','LPLEX','LLENS','RLENS','LEYE','REYE','LOPTIC','ROPTIC','CHIASM','LIPS']

# %%
len(index_)
# Out:
# 7

# %%
len(pddca_classes)
# Out:
# 7

# %%
# import torch, numpy as np, warnings
# this is the function to one-hot-encode data
def onehot(outs, targ, argmax=True):
    # Metrics requiring one hot encoded targets, pass through sigmoid or softmax
    # convert to one hot encoded target...
    shape = targ.size()
    print(len(shape), shape, outs.size())
    batch = shape[0]
    # calculate argmax...
    if argmax is True:
        outs = torch.softmax(outs, dim=1)
        outs = torch.argmax(outs, dim=1)
    
    class_ = int(torch.max(targ).item())
    print(class_)
    
    if len(shape) == 4:
        sh = (batch, class_ + 1, shape[1], shape[2], shape[3])
        print(sh)
        targets_dice = torch.zeros(sh, dtype=torch.float)
        targets_out = torch.zeros(sh, dtype=torch.float)
    else:
        sh = (1, class_ + 1, shape[0], shape[1], shape[2])
        print(sh)
        targets_dice = torch.zeros(sh, dtype=torch.float)
        targets_out = torch.zeros(sh, dtype=torch.float)

    for i in range( class_ + 1):
        targets_dice[0, i][targ[0] == i] = 1
        targets_out[0, i][outs[0] == i] = 1

    return targets_out, targets_dice

# %%
def resample_sitk(image, mode="linear", new_spacing=None, filter=False ): # new_spacing=np.array((1.0, 1.0, 2.0)) , filter=True
    if new_spacing is not None: # originally taken from https://github.com/SimpleITK/SimpleITK/issues/561
        resample = sitk.ResampleImageFilter()
        if mode == "linear":
            resample.SetInterpolator = sitk.sitkLinear  # use linear to resample image
        else: # use sitkNearestNeighbor interpolation # best for masks
            resample.SetInterpolator = sitk.sitkNearestNeighbor
        orig_size = np.array(image.GetSize(), dtype=np.int)
        orig_spacing = np.array(image.GetSpacing())
        resample.SetOutputDirection(image.GetDirection())
        resample.SetOutputOrigin(image.GetOrigin())
        resample.SetOutputPixelType(image.GetPixelIDValue())
        new_spacing = new_spacing
        resample.SetOutputSpacing(new_spacing)
        new_size = orig_size * (orig_spacing / new_spacing)
        new_size = np.ceil(new_size).astype(np.int)
        new_size = [int(s) for s in new_size]
        resample.SetSize(new_size)
        if filter is True: # fights artifacts produced by analaising # only do this when resampling image (not mask...)
            img = resample.Execute(sitk.SmoothingRecursiveGaussian(image, 2.0))
        else:
            img = resample.Execute(image)
    else: # do nothing to the image...
        img = image
    return img

# %%
oars = []
pddca_oars = []
dce =  []
hd =   []
sd =   []
ob = []
p_ = []

# %%
# path of folders...
# observer = 'radiographer'
path = f'/Users/joemarsilla/Downloads/data/PDDCA/' 

for i, pat in enumerate(p):
    path_ = path+pat+'/structures/'
    # load subsequent patient outputs from model...
    # f'/Users/joemarsilla/Downloads/out/outs_{i}_FULL.npy' #
    out_path = f"/Users/joemarsilla/Downloads/pred/pddca2/FINAL_/outs_{i}_FULL.nrrd"
    # f'/Users/joemarsilla/Downloads/test/outs_{i}_FULL.npy' # 
    # outputs = torch.from_numpy(np.load(out_path))
    outputs = torch.from_numpy(nrrd.read(out_path)[0])
    # targets = torch.from_numpy(np.load(out_path.replace('outs', 'in')))
    outputs, _ = onehot(outputs.unsqueeze(0), outputs.unsqueeze(0), argmax=False)
    try:
        for k, val in enumerate(index_):
            try:
                targ = sitk.ReadImage(path_+pddca_classes[k]+'.nrrd')
        #       img = self.resample_sitk(img, new_spacing=np.array((1.0, 1.0, 2.0)))
        #       targ = resample_sitk(targ, mode="nearest", new_spacing=np.array((1.0, 1.0, 2.0)))
                targ = torch.tensor(sitk.GetArrayFromImage(targ))
                tsize = targ.size()
                print(tsize)
                outs = outputs[0,val]
                osize = outs.size()
                if osize[0] != tsize[0]:
                    diff = osize[0] - tsize[0]
                    a = diff//2
                    difff = diff - a
                    outs = outs[a:osize[0]-difff]
                    osize = outs.size()
                    assert osize[0] == tsize[0]
                print(osize)
                if osize[0]>tsize[0]:
                    diff = osize[0] - tsize[0]
                    a = diff//2
                    difff = diff - a
                    outs = outs[a:osize[0]-difff]
                
                outs = outs[osize[0]//8:osize[0]-osize[0]//8]
                targ = targ[osize[0]//8:osize[0]-osize[0]//8]
                dc = met.compute_meandice(outs.unsqueeze(0).unsqueeze(0), targ.unsqueeze(0).unsqueeze(0))
                h  = met.compute_hausdorff_distance(outs.unsqueeze(0).unsqueeze(0), targ.unsqueeze(0).unsqueeze(0), percentile=95, include_background=False)
                s  = met.compute_average_surface_distance(outs.unsqueeze(0).unsqueeze(0), targ.unsqueeze(0).unsqueeze(0), include_background=False)
                print(chosen[val-1], dc, h)
                # save metrics...
                dce.append(dc[0][0].item())
                hd.append(h[0][0].item())
                sd.append(s[0][0].item())
        #       ob.append(observer)
                pddca_oars.append(pddca_classes[k])
                oars.append(chosen[val-1])
                p_.append(pat)
            except Exception as e:
                print(e)
                print(f'No {val} in {p[i]}')
    except Exception as e:
        print(e)
        print(p[i], ' is BAD.')
    
#     break
# Out:
# 4 torch.Size([1, 112, 512, 512]) torch.Size([1, 112, 512, 512])
# 19
# (1, 20, 112, 512, 512)
# torch.Size([107, 512, 512])
# torch.Size([107, 512, 512])
# BSTEM tensor([[0.6156]]) tensor([[5.3852]], dtype=torch.float64)
# torch.Size([107, 512, 512])
# torch.Size([107, 512, 512])
# CHIASM tensor([[0.2538]]) tensor([[5.7446]], dtype=torch.float64)
# torch.Size([107, 512, 512])
# torch.Size([107, 512, 512])
# MAND tensor([[0.7926]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([107, 512, 512])
# torch.Size([107, 512, 512])
# LOPTIC tensor([[0.4738]]) tensor([[1.9732]], dtype=torch.float64)
# torch.Size([107, 512, 512])
# torch.Size([107, 512, 512])
# ROPTIC tensor([[0.4563]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([107, 512, 512])
# torch.Size([107, 512, 512])
# LPAR tensor([[0.7937]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([107, 512, 512])
# torch.Size([107, 512, 512])
# RPAR tensor([[0.7648]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 130, 512, 512]) torch.Size([1, 130, 512, 512])
# 19
# (1, 20, 130, 512, 512)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# BSTEM tensor([[0.7243]]) tensor([[4.5826]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# CHIASM tensor([[0.3723]]) tensor([[5.0842]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# MAND tensor([[0.8352]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LOPTIC tensor([[0.5808]]) tensor([[1.9707]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# ROPTIC tensor([[0.5293]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LPAR tensor([[0.8600]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# RPAR tensor([[0.8192]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 134, 512, 512]) torch.Size([1, 134, 512, 512])
# 19
# (1, 20, 134, 512, 512)
# torch.Size([134, 512, 512])
# torch.Size([134, 512, 512])
# BSTEM tensor([[0.7575]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([134, 512, 512])
# torch.Size([134, 512, 512])
# CHIASM tensor([[0.3447]]) tensor([[4.3589]], dtype=torch.float64)
# torch.Size([134, 512, 512])
# torch.Size([134, 512, 512])
# MAND tensor([[0.8199]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([134, 512, 512])
# torch.Size([134, 512, 512])
# LOPTIC tensor([[0.5787]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([134, 512, 512])
# torch.Size([134, 512, 512])
# ROPTIC tensor([[0.5507]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([134, 512, 512])
# torch.Size([134, 512, 512])
# LPAR tensor([[0.8527]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([134, 512, 512])
# torch.Size([134, 512, 512])
# RPAR tensor([[0.8588]]) tensor([[2.2361]], dtype=torch.float64)
# 4 torch.Size([1, 144, 512, 512]) torch.Size([1, 144, 512, 512])
# 19
# (1, 20, 144, 512, 512)
# torch.Size([144, 512, 512])
# torch.Size([144, 512, 512])
# BSTEM tensor([[0.7446]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([144, 512, 512])
# torch.Size([144, 512, 512])
# CHIASM tensor([[0.3806]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([144, 512, 512])
# torch.Size([144, 512, 512])
# MAND tensor([[0.8477]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([144, 512, 512])
# torch.Size([144, 512, 512])
# LOPTIC tensor([[0.5423]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([144, 512, 512])
# torch.Size([144, 512, 512])
# ROPTIC tensor([[0.5429]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([144, 512, 512])
# torch.Size([144, 512, 512])
# LPAR tensor([[0.7811]]) tensor([[6.1644]], dtype=torch.float64)
# torch.Size([144, 512, 512])
# torch.Size([144, 512, 512])
# RPAR tensor([[0.8590]]) tensor([[2.]], dtype=torch.float64)
# 4 torch.Size([1, 138, 512, 512]) torch.Size([1, 138, 512, 512])
# 19
# (1, 20, 138, 512, 512)
# torch.Size([138, 512, 512])
# torch.Size([138, 512, 512])
# BSTEM tensor([[0.7469]]) tensor([[3.3166]], dtype=torch.float64)
# torch.Size([138, 512, 512])
# torch.Size([138, 512, 512])
# CHIASM tensor([[0.3358]]) tensor([[6.3246]], dtype=torch.float64)
# torch.Size([138, 512, 512])
# torch.Size([138, 512, 512])
# MAND tensor([[0.8241]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([138, 512, 512])
# torch.Size([138, 512, 512])
# LOPTIC tensor([[0.5751]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([138, 512, 512])
# torch.Size([138, 512, 512])
# ROPTIC tensor([[0.5714]]) tensor([[1.6049]], dtype=torch.float64)
# torch.Size([138, 512, 512])
# torch.Size([138, 512, 512])
# LPAR tensor([[0.8115]]) tensor([[4.]], dtype=torch.float64)
# torch.Size([138, 512, 512])
# torch.Size([138, 512, 512])
# RPAR tensor([[0.7827]]) tensor([[5.]], dtype=torch.float64)
# 4 torch.Size([1, 159, 512, 512]) torch.Size([1, 159, 512, 512])
# 19
# (1, 20, 159, 512, 512)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# BSTEM tensor([[0.7135]]) tensor([[4.6904]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# CHIASM tensor([[0.3415]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# MAND tensor([[0.8462]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# LOPTIC tensor([[0.5698]]) tensor([[2.8073]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# ROPTIC tensor([[0.5079]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# LPAR tensor([[0.6862]]) tensor([[5.3852]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# RPAR tensor([[0.8148]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 156, 512, 512]) torch.Size([1, 156, 512, 512])
# 19
# (1, 20, 156, 512, 512)
# torch.Size([156, 512, 512])
# torch.Size([156, 512, 512])
# BSTEM tensor([[0.7676]]) tensor([[3.7417]], dtype=torch.float64)
# torch.Size([156, 512, 512])
# torch.Size([156, 512, 512])
# CHIASM tensor([[0.2281]]) tensor([[6.4031]], dtype=torch.float64)
# torch.Size([156, 512, 512])
# torch.Size([156, 512, 512])
# MAND tensor([[0.8173]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([156, 512, 512])
# torch.Size([156, 512, 512])
# LOPTIC tensor([[0.4828]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([156, 512, 512])
# torch.Size([156, 512, 512])
# ROPTIC tensor([[0.5802]]) tensor([[4.9165]], dtype=torch.float64)
# torch.Size([156, 512, 512])
# torch.Size([156, 512, 512])
# LPAR tensor([[0.8071]]) tensor([[6.0828]], dtype=torch.float64)
# torch.Size([156, 512, 512])
# torch.Size([156, 512, 512])
# RPAR tensor([[0.7951]]) tensor([[2.2361]], dtype=torch.float64)
# 4 torch.Size([1, 145, 512, 512]) torch.Size([1, 145, 512, 512])
# 19
# (1, 20, 145, 512, 512)
# torch.Size([145, 512, 512])
# torch.Size([145, 512, 512])
# BSTEM tensor([[0.8546]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([145, 512, 512])
# torch.Size([145, 512, 512])
# /usr/local/anaconda3/lib/python3.9/site-packages/monai/metrics/hausdorff_distance.py:158: UserWarning: the ground truth of class 0 is all 0, this may result in nan/inf distance.
#   warnings.warn(f"the ground truth of class {c} is all 0, this may result in nan/inf distance.")
# /usr/local/anaconda3/lib/python3.9/site-packages/monai/metrics/hausdorff_distance.py:160: UserWarning: the prediction of class 0 is all 0, this may result in nan/inf distance.
#   warnings.warn(f"the prediction of class {c} is all 0, this may result in nan/inf distance.")
# /usr/local/anaconda3/lib/python3.9/site-packages/monai/metrics/surface_distance.py:153: UserWarning: the ground truth of class 0 is all 0, this may result in nan/inf distance.
#   warnings.warn(f"the ground truth of class {c} is all 0, this may result in nan/inf distance.")
# /usr/local/anaconda3/lib/python3.9/site-packages/monai/metrics/surface_distance.py:155: UserWarning: the prediction of class 0 is all 0, this may result in nan/inf distance.
#   warnings.warn(f"the prediction of class {c} is all 0, this may result in nan/inf distance.")
# CHIASM tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([145, 512, 512])
# torch.Size([145, 512, 512])
# MAND tensor([[0.8227]]) tensor([[1.5890]], dtype=torch.float64)
# torch.Size([145, 512, 512])
# torch.Size([145, 512, 512])
# LOPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([145, 512, 512])
# torch.Size([145, 512, 512])
# ROPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([145, 512, 512])
# torch.Size([145, 512, 512])
# LPAR tensor([[0.7893]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([145, 512, 512])
# torch.Size([145, 512, 512])
# RPAR tensor([[0.8616]]) tensor([[4.5826]], dtype=torch.float64)
# 4 torch.Size([1, 128, 512, 512]) torch.Size([1, 128, 512, 512])
# 19
# (1, 20, 128, 512, 512)
# torch.Size([128, 512, 512])
# torch.Size([128, 512, 512])
# BSTEM tensor([[0.7824]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([128, 512, 512])
# torch.Size([128, 512, 512])
# CHIASM tensor([[0.2623]]) tensor([[7.8740]], dtype=torch.float64)
# torch.Size([128, 512, 512])
# torch.Size([128, 512, 512])
# MAND tensor([[0.8498]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([128, 512, 512])
# torch.Size([128, 512, 512])
# LOPTIC tensor([[0.5826]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([128, 512, 512])
# torch.Size([128, 512, 512])
# ROPTIC tensor([[0.5571]]) tensor([[2.7988]], dtype=torch.float64)
# torch.Size([128, 512, 512])
# torch.Size([128, 512, 512])
# LPAR tensor([[0.8430]]) tensor([[3.3166]], dtype=torch.float64)
# torch.Size([128, 512, 512])
# torch.Size([128, 512, 512])
# RPAR tensor([[0.8341]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 130, 512, 512]) torch.Size([1, 130, 512, 512])
# 19
# (1, 20, 130, 512, 512)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# BSTEM tensor([[0.7770]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# CHIASM tensor([[0.3961]]) tensor([[8.2370]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# MAND tensor([[0.8160]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LOPTIC tensor([[0.5225]]) tensor([[5.9076]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# ROPTIC tensor([[0.6082]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LPAR tensor([[0.8734]]) tensor([[7.7780]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# RPAR tensor([[0.8635]]) tensor([[4.]], dtype=torch.float64)
# 4 torch.Size([1, 130, 512, 512]) torch.Size([1, 130, 512, 512])
# 19
# (1, 20, 130, 512, 512)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# BSTEM tensor([[0.7343]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# CHIASM tensor([[0.2830]]) tensor([[8.2611]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# MAND tensor([[0.8068]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LOPTIC tensor([[0.5748]]) tensor([[2.8284]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# ROPTIC tensor([[0.4637]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LPAR tensor([[0.8613]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# RPAR tensor([[0.8534]]) tensor([[2.8284]], dtype=torch.float64)
# 4 torch.Size([1, 160, 512, 512]) torch.Size([1, 160, 512, 512])
# 19
# (1, 20, 160, 512, 512)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# BSTEM tensor([[0.8069]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# CHIASM tensor([[0.3252]]) tensor([[6.4031]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# MAND tensor([[0.8296]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# LOPTIC tensor([[0.4665]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# ROPTIC tensor([[0.4916]]) tensor([[4.9791]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# LPAR tensor([[0.8326]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# RPAR tensor([[0.8415]]) tensor([[3.1623]], dtype=torch.float64)
# 4 torch.Size([1, 112, 512, 512]) torch.Size([1, 112, 512, 512])
# 19
# (1, 20, 112, 512, 512)
# torch.Size([76, 512, 512])
# torch.Size([76, 512, 512])
# BSTEM tensor([[0.8303]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([76, 512, 512])
# torch.Size([76, 512, 512])
# CHIASM tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([76, 512, 512])
# torch.Size([76, 512, 512])
# MAND tensor([[0.7741]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([76, 512, 512])
# torch.Size([76, 512, 512])
# LOPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([76, 512, 512])
# torch.Size([76, 512, 512])
# ROPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([76, 512, 512])
# torch.Size([76, 512, 512])
# LPAR tensor([[0.8430]]) tensor([[3.7417]], dtype=torch.float64)
# torch.Size([76, 512, 512])
# torch.Size([76, 512, 512])
# RPAR tensor([[0.8308]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 115, 512, 512]) torch.Size([1, 115, 512, 512])
# 19
# (1, 20, 115, 512, 512)
# torch.Size([115, 512, 512])
# torch.Size([115, 512, 512])
# BSTEM tensor([[0.7281]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([115, 512, 512])
# torch.Size([115, 512, 512])
# CHIASM tensor([[0.4710]]) tensor([[7.5319]], dtype=torch.float64)
# torch.Size([115, 512, 512])
# torch.Size([115, 512, 512])
# MAND tensor([[0.8104]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([115, 512, 512])
# torch.Size([115, 512, 512])
# LOPTIC tensor([[0.5487]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([115, 512, 512])
# torch.Size([115, 512, 512])
# ROPTIC tensor([[0.5228]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([115, 512, 512])
# torch.Size([115, 512, 512])
# LPAR tensor([[0.8767]]) tensor([[2.8284]], dtype=torch.float64)
# torch.Size([115, 512, 512])
# torch.Size([115, 512, 512])
# RPAR tensor([[0.8247]]) tensor([[5.9161]], dtype=torch.float64)
# 4 torch.Size([1, 272, 512, 512]) torch.Size([1, 272, 512, 512])
# 18
# (1, 19, 272, 512, 512)
# torch.Size([272, 512, 512])
# torch.Size([272, 512, 512])
# BSTEM tensor([[0.2285]]) tensor([[18.6011]], dtype=torch.float64)
# torch.Size([272, 512, 512])
# torch.Size([272, 512, 512])
# CHIASM tensor([[0.2468]]) tensor([[16.5227]], dtype=torch.float64)
# torch.Size([272, 512, 512])
# torch.Size([272, 512, 512])
# MAND tensor([[0.7190]]) tensor([[111.5572]], dtype=torch.float64)
# torch.Size([272, 512, 512])
# torch.Size([272, 512, 512])
# LOPTIC tensor([[0.5107]]) tensor([[7.0711]], dtype=torch.float64)
# torch.Size([272, 512, 512])
# torch.Size([272, 512, 512])
# ROPTIC tensor([[0.6509]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([272, 512, 512])
# torch.Size([272, 512, 512])
# LPAR tensor([[0.6025]]) tensor([[12.2066]], dtype=torch.float64)
# torch.Size([272, 512, 512])
# torch.Size([272, 512, 512])
# RPAR tensor([[0.7249]]) tensor([[9.4340]], dtype=torch.float64)
# 4 torch.Size([1, 129, 512, 512]) torch.Size([1, 129, 512, 512])
# 19
# (1, 20, 129, 512, 512)
# torch.Size([129, 512, 512])
# torch.Size([129, 512, 512])
# BSTEM tensor([[0.7008]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([129, 512, 512])
# torch.Size([129, 512, 512])
# CHIASM tensor([[0.2881]]) tensor([[6.5164]], dtype=torch.float64)
# torch.Size([129, 512, 512])
# torch.Size([129, 512, 512])
# MAND tensor([[0.8040]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([129, 512, 512])
# torch.Size([129, 512, 512])
# LOPTIC tensor([[0.4896]]) tensor([[31.0437]], dtype=torch.float64)
# torch.Size([129, 512, 512])
# torch.Size([129, 512, 512])
# ROPTIC tensor([[0.5054]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([129, 512, 512])
# torch.Size([129, 512, 512])
# LPAR tensor([[0.8693]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([129, 512, 512])
# torch.Size([129, 512, 512])
# RPAR tensor([[0.8878]]) tensor([[2.8284]], dtype=torch.float64)
# 4 torch.Size([1, 150, 512, 512]) torch.Size([1, 150, 512, 512])
# 19
# (1, 20, 150, 512, 512)
# torch.Size([150, 512, 512])
# torch.Size([150, 512, 512])
# BSTEM tensor([[0.7307]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([150, 512, 512])
# torch.Size([150, 512, 512])
# CHIASM tensor([[0.3698]]) tensor([[10.8628]], dtype=torch.float64)
# torch.Size([150, 512, 512])
# torch.Size([150, 512, 512])
# MAND tensor([[0.8110]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([150, 512, 512])
# torch.Size([150, 512, 512])
# LOPTIC tensor([[0.5128]]) tensor([[7.1551]], dtype=torch.float64)
# torch.Size([150, 512, 512])
# torch.Size([150, 512, 512])
# ROPTIC tensor([[0.5042]]) tensor([[8.2290]], dtype=torch.float64)
# torch.Size([150, 512, 512])
# torch.Size([150, 512, 512])
# LPAR tensor([[0.8592]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([150, 512, 512])
# torch.Size([150, 512, 512])
# RPAR tensor([[0.8438]]) tensor([[5.]], dtype=torch.float64)
# 4 torch.Size([1, 136, 512, 512]) torch.Size([1, 136, 512, 512])
# 19
# (1, 20, 136, 512, 512)
# torch.Size([136, 512, 512])
# torch.Size([136, 512, 512])
# BSTEM tensor([[0.7762]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([136, 512, 512])
# torch.Size([136, 512, 512])
# CHIASM tensor([[0.2575]]) tensor([[8.0340]], dtype=torch.float64)
# torch.Size([136, 512, 512])
# torch.Size([136, 512, 512])
# MAND tensor([[0.7925]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([136, 512, 512])
# torch.Size([136, 512, 512])
# LOPTIC tensor([[0.5353]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([136, 512, 512])
# torch.Size([136, 512, 512])
# ROPTIC tensor([[0.4846]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([136, 512, 512])
# torch.Size([136, 512, 512])
# LPAR tensor([[0.8574]]) tensor([[6.1644]], dtype=torch.float64)
# torch.Size([136, 512, 512])
# torch.Size([136, 512, 512])
# RPAR tensor([[0.8846]]) tensor([[6.0828]], dtype=torch.float64)
# 4 torch.Size([1, 139, 512, 512]) torch.Size([1, 139, 512, 512])
# 19
# (1, 20, 139, 512, 512)
# torch.Size([139, 512, 512])
# torch.Size([139, 512, 512])
# BSTEM tensor([[0.6943]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([139, 512, 512])
# torch.Size([139, 512, 512])
# CHIASM tensor([[0.4697]]) tensor([[5.4772]], dtype=torch.float64)
# torch.Size([139, 512, 512])
# torch.Size([139, 512, 512])
# MAND tensor([[0.7469]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([139, 512, 512])
# torch.Size([139, 512, 512])
# LOPTIC tensor([[0.4984]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([139, 512, 512])
# torch.Size([139, 512, 512])
# ROPTIC tensor([[0.4795]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([139, 512, 512])
# torch.Size([139, 512, 512])
# LPAR tensor([[0.8481]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([139, 512, 512])
# torch.Size([139, 512, 512])
# RPAR tensor([[0.6318]]) tensor([[10.8167]], dtype=torch.float64)
# 4 torch.Size([1, 130, 512, 512]) torch.Size([1, 130, 512, 512])
# 19
# (1, 20, 130, 512, 512)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# BSTEM tensor([[0.6568]]) tensor([[4.]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# CHIASM tensor([[0.2419]]) tensor([[6.0497]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# MAND tensor([[0.7965]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LOPTIC tensor([[0.5941]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# ROPTIC tensor([[0.4808]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# LPAR tensor([[0.8590]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([130, 512, 512])
# torch.Size([130, 512, 512])
# RPAR tensor([[0.8536]]) tensor([[2.4495]], dtype=torch.float64)
# 4 torch.Size([1, 162, 512, 512]) torch.Size([1, 162, 512, 512])
# 19
# (1, 20, 162, 512, 512)
# torch.Size([162, 512, 512])
# torch.Size([162, 512, 512])
# BSTEM tensor([[0.7723]]) tensor([[3.7417]], dtype=torch.float64)
# torch.Size([162, 512, 512])
# torch.Size([162, 512, 512])
# CHIASM tensor([[0.3391]]) tensor([[7.0816]], dtype=torch.float64)
# torch.Size([162, 512, 512])
# torch.Size([162, 512, 512])
# MAND tensor([[0.8299]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([162, 512, 512])
# torch.Size([162, 512, 512])
# LOPTIC tensor([[0.6185]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([162, 512, 512])
# torch.Size([162, 512, 512])
# ROPTIC tensor([[0.5913]]) tensor([[2.3249]], dtype=torch.float64)
# torch.Size([162, 512, 512])
# torch.Size([162, 512, 512])
# LPAR tensor([[0.8569]]) tensor([[3.3166]], dtype=torch.float64)
# torch.Size([162, 512, 512])
# torch.Size([162, 512, 512])
# RPAR tensor([[0.8618]]) tensor([[3.3166]], dtype=torch.float64)
# 4 torch.Size([1, 176, 512, 512]) torch.Size([1, 176, 512, 512])
# 19
# (1, 20, 176, 512, 512)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# BSTEM tensor([[0.7652]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# CHIASM tensor([[0.2839]]) tensor([[9.6437]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# MAND tensor([[0.7937]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# LOPTIC tensor([[0.5478]]) tensor([[7.3808]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# ROPTIC tensor([[0.4684]]) tensor([[6.1419]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# LPAR tensor([[0.7764]]) tensor([[4.5826]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# RPAR tensor([[0.8958]]) tensor([[2.2361]], dtype=torch.float64)
# 4 torch.Size([1, 119, 512, 512]) torch.Size([1, 119, 512, 512])
# 19
# (1, 20, 119, 512, 512)
# torch.Size([119, 512, 512])
# torch.Size([119, 512, 512])
# BSTEM tensor([[0.8490]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([119, 512, 512])
# torch.Size([119, 512, 512])
# CHIASM tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([119, 512, 512])
# torch.Size([119, 512, 512])
# MAND tensor([[0.7934]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([119, 512, 512])
# torch.Size([119, 512, 512])
# LOPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([119, 512, 512])
# torch.Size([119, 512, 512])
# ROPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([119, 512, 512])
# torch.Size([119, 512, 512])
# LPAR tensor([[0.8164]]) tensor([[3.3166]], dtype=torch.float64)
# torch.Size([119, 512, 512])
# torch.Size([119, 512, 512])
# RPAR tensor([[0.7987]]) tensor([[4.2426]], dtype=torch.float64)
# 4 torch.Size([1, 160, 512, 512]) torch.Size([1, 160, 512, 512])
# 19
# (1, 20, 160, 512, 512)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# BSTEM tensor([[0.7401]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# CHIASM tensor([[0.2454]]) tensor([[9.2736]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# MAND tensor([[0.8346]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# LOPTIC tensor([[0.5750]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# ROPTIC tensor([[0.5013]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# LPAR tensor([[0.8418]]) tensor([[4.]], dtype=torch.float64)
# torch.Size([160, 512, 512])
# torch.Size([160, 512, 512])
# RPAR tensor([[0.8291]]) tensor([[5.]], dtype=torch.float64)
# 4 torch.Size([1, 194, 512, 512]) torch.Size([1, 194, 512, 512])
# 19
# (1, 20, 194, 512, 512)
# torch.Size([194, 512, 512])
# torch.Size([194, 512, 512])
# BSTEM tensor([[0.7161]]) tensor([[4.]], dtype=torch.float64)
# torch.Size([194, 512, 512])
# torch.Size([194, 512, 512])
# CHIASM tensor([[0.2177]]) tensor([[10.0499]], dtype=torch.float64)
# torch.Size([194, 512, 512])
# torch.Size([194, 512, 512])
# MAND tensor([[0.8049]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([194, 512, 512])
# torch.Size([194, 512, 512])
# LOPTIC tensor([[0.5841]]) tensor([[3.3166]], dtype=torch.float64)
# torch.Size([194, 512, 512])
# torch.Size([194, 512, 512])
# ROPTIC tensor([[0.5621]]) tensor([[6.4031]], dtype=torch.float64)
# torch.Size([194, 512, 512])
# torch.Size([194, 512, 512])
# LPAR tensor([[0.7941]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([194, 512, 512])
# torch.Size([194, 512, 512])
# RPAR tensor([[0.8336]]) tensor([[2.4495]], dtype=torch.float64)
# 4 torch.Size([1, 126, 512, 512]) torch.Size([1, 126, 512, 512])
# 19
# (1, 20, 126, 512, 512)
# torch.Size([126, 512, 512])
# torch.Size([126, 512, 512])
# BSTEM tensor([[0.6831]]) tensor([[4.]], dtype=torch.float64)
# torch.Size([126, 512, 512])
# torch.Size([126, 512, 512])
# CHIASM tensor([[0.3287]]) tensor([[5.0990]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0329/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0329
# torch.Size([126, 512, 512])
# torch.Size([126, 512, 512])
# LOPTIC tensor([[0.6430]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([126, 512, 512])
# torch.Size([126, 512, 512])
# ROPTIC tensor([[0.4667]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([126, 512, 512])
# torch.Size([126, 512, 512])
# LPAR tensor([[0.5435]]) tensor([[6.3678]], dtype=torch.float64)
# torch.Size([126, 512, 512])
# torch.Size([126, 512, 512])
# RPAR tensor([[0.5840]]) tensor([[5.7446]], dtype=torch.float64)
# 4 torch.Size([1, 181, 512, 512]) torch.Size([1, 181, 512, 512])
# 19
# (1, 20, 181, 512, 512)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# BSTEM tensor([[0.7470]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# CHIASM tensor([[0.0815]]) tensor([[14.3944]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0330/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0330
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# LOPTIC tensor([[0.5501]]) tensor([[9.9499]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# ROPTIC tensor([[0.5572]]) tensor([[7.8229]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# LPAR tensor([[0.8498]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# RPAR tensor([[0.8468]]) tensor([[3.1623]], dtype=torch.float64)
# 4 torch.Size([1, 170, 512, 512]) torch.Size([1, 170, 512, 512])
# 19
# (1, 20, 170, 512, 512)
# torch.Size([170, 512, 512])
# torch.Size([170, 512, 512])
# BSTEM tensor([[0.7239]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([170, 512, 512])
# torch.Size([170, 512, 512])
# CHIASM tensor([[0.3093]]) tensor([[9.]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0427/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0427
# torch.Size([170, 512, 512])
# torch.Size([170, 512, 512])
# LOPTIC tensor([[0.5069]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([170, 512, 512])
# torch.Size([170, 512, 512])
# ROPTIC tensor([[0.4819]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([170, 512, 512])
# torch.Size([170, 512, 512])
# LPAR tensor([[0.8817]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([170, 512, 512])
# torch.Size([170, 512, 512])
# RPAR tensor([[0.8933]]) tensor([[2.4495]], dtype=torch.float64)
# 4 torch.Size([1, 124, 512, 512]) torch.Size([1, 124, 512, 512])
# 19
# (1, 20, 124, 512, 512)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# BSTEM tensor([[0.7986]]) tensor([[2.8284]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# CHIASM tensor([[0.2938]]) tensor([[6.7156]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0433/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0433
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# LOPTIC tensor([[0.4146]]) tensor([[5.8607]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# ROPTIC tensor([[0.4480]]) tensor([[5.6433]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# LPAR tensor([[0.8424]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# RPAR tensor([[0.8667]]) tensor([[2.4495]], dtype=torch.float64)
# 4 torch.Size([1, 360, 512, 512]) torch.Size([1, 360, 512, 512])
# 19
# (1, 20, 360, 512, 512)
# torch.Size([360, 512, 512])
# torch.Size([360, 512, 512])
# BSTEM tensor([[0.8500]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([360, 512, 512])
# torch.Size([360, 512, 512])
# CHIASM tensor([[0.1543]]) tensor([[3.6056]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0441/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0441
# torch.Size([360, 512, 512])
# torch.Size([360, 512, 512])
# LOPTIC tensor([[0.5559]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([360, 512, 512])
# torch.Size([360, 512, 512])
# ROPTIC tensor([[0.4011]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([360, 512, 512])
# torch.Size([360, 512, 512])
# LPAR tensor([[0.8501]]) tensor([[3.3166]], dtype=torch.float64)
# torch.Size([360, 512, 512])
# torch.Size([360, 512, 512])
# RPAR tensor([[0.8621]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 125, 512, 512]) torch.Size([1, 125, 512, 512])
# 19
# (1, 20, 125, 512, 512)
# torch.Size([125, 512, 512])
# torch.Size([125, 512, 512])
# BSTEM tensor([[0.7472]]) tensor([[4.]], dtype=torch.float64)
# torch.Size([125, 512, 512])
# torch.Size([125, 512, 512])
# CHIASM tensor([[0.3739]]) tensor([[5.4772]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0455/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0455
# torch.Size([125, 512, 512])
# torch.Size([125, 512, 512])
# LOPTIC tensor([[0.4933]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([125, 512, 512])
# torch.Size([125, 512, 512])
# ROPTIC tensor([[0.5905]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([125, 512, 512])
# torch.Size([125, 512, 512])
# LPAR tensor([[0.8808]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([125, 512, 512])
# torch.Size([125, 512, 512])
# RPAR tensor([[0.8626]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 181, 512, 512]) torch.Size([1, 181, 512, 512])
# 19
# (1, 20, 181, 512, 512)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# BSTEM tensor([[0.7805]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# CHIASM tensor([[0.3319]]) tensor([[5.0693]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0457/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0457
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# LOPTIC tensor([[0.4333]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# ROPTIC tensor([[0.4691]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# LPAR tensor([[0.8257]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([181, 512, 512])
# torch.Size([181, 512, 512])
# RPAR tensor([[0.8999]]) tensor([[2.2361]], dtype=torch.float64)
# 4 torch.Size([1, 176, 512, 512]) torch.Size([1, 176, 512, 512])
# 19
# (1, 20, 176, 512, 512)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# BSTEM tensor([[0.7379]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# CHIASM tensor([[0.3216]]) tensor([[7.6811]], dtype=torch.float64)
# Exception thrown in SimpleITK ImageFileReader_Execute: /Users/runner/work/1/sitk/Code/IO/src/sitkImageReaderBase.cxx:97:
# sitk::ERROR: The file "/Users/joemarsilla/Downloads/data/PDDCA/0522c0479/structures/Mandible.nrrd" does not exist.
# No 5 in 0522c0479
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# LOPTIC tensor([[0.5365]]) tensor([[4.3918]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# ROPTIC tensor([[0.5215]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# LPAR tensor([[0.8074]]) tensor([[4.]], dtype=torch.float64)
# torch.Size([176, 512, 512])
# torch.Size([176, 512, 512])
# RPAR tensor([[0.8225]]) tensor([[4.5826]], dtype=torch.float64)
# 4 torch.Size([1, 263, 512, 512]) torch.Size([1, 263, 512, 512])
# 19
# (1, 20, 263, 512, 512)
# torch.Size([263, 512, 512])
# torch.Size([263, 512, 512])
# BSTEM tensor([[0.6868]]) tensor([[5.0990]], dtype=torch.float64)
# torch.Size([263, 512, 512])
# torch.Size([263, 512, 512])
# CHIASM tensor([[0.1960]]) tensor([[10.5157]], dtype=torch.float64)
# torch.Size([263, 512, 512])
# torch.Size([263, 512, 512])
# MAND tensor([[0.8665]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([263, 512, 512])
# torch.Size([263, 512, 512])
# LOPTIC tensor([[0.4617]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([263, 512, 512])
# torch.Size([263, 512, 512])
# ROPTIC tensor([[0.4254]]) tensor([[2.1534]], dtype=torch.float64)
# torch.Size([263, 512, 512])
# torch.Size([263, 512, 512])
# LPAR tensor([[0.8519]]) tensor([[2.8284]], dtype=torch.float64)
# torch.Size([263, 512, 512])
# torch.Size([263, 512, 512])
# RPAR tensor([[0.8842]]) tensor([[2.4495]], dtype=torch.float64)
# 4 torch.Size([1, 204, 512, 512]) torch.Size([1, 204, 512, 512])
# 19
# (1, 20, 204, 512, 512)
# torch.Size([204, 512, 512])
# torch.Size([204, 512, 512])
# BSTEM tensor([[0.7387]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([204, 512, 512])
# torch.Size([204, 512, 512])
# CHIASM tensor([[0.3076]]) tensor([[7.8740]], dtype=torch.float64)
# torch.Size([204, 512, 512])
# torch.Size([204, 512, 512])
# MAND tensor([[0.8015]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([204, 512, 512])
# torch.Size([204, 512, 512])
# LOPTIC tensor([[0.5517]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([204, 512, 512])
# torch.Size([204, 512, 512])
# ROPTIC tensor([[0.5221]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([204, 512, 512])
# torch.Size([204, 512, 512])
# LPAR tensor([[0.8717]]) tensor([[2.4281]], dtype=torch.float64)
# torch.Size([204, 512, 512])
# torch.Size([204, 512, 512])
# RPAR tensor([[0.8829]]) tensor([[2.4495]], dtype=torch.float64)
# 4 torch.Size([1, 135, 512, 512]) torch.Size([1, 135, 512, 512])
# 19
# (1, 20, 135, 512, 512)
# torch.Size([135, 512, 512])
# torch.Size([135, 512, 512])
# BSTEM tensor([[0.6548]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([135, 512, 512])
# torch.Size([135, 512, 512])
# CHIASM tensor([[0.4269]]) tensor([[6.1562]], dtype=torch.float64)
# torch.Size([135, 512, 512])
# torch.Size([135, 512, 512])
# MAND tensor([[0.8461]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([135, 512, 512])
# torch.Size([135, 512, 512])
# LOPTIC tensor([[0.4359]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([135, 512, 512])
# torch.Size([135, 512, 512])
# ROPTIC tensor([[0.4263]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([135, 512, 512])
# torch.Size([135, 512, 512])
# LPAR tensor([[0.8781]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([135, 512, 512])
# torch.Size([135, 512, 512])
# RPAR tensor([[0.8813]]) tensor([[2.4495]], dtype=torch.float64)
# 4 torch.Size([1, 165, 512, 512]) torch.Size([1, 165, 512, 512])
# 19
# (1, 20, 165, 512, 512)
# torch.Size([165, 512, 512])
# torch.Size([165, 512, 512])
# BSTEM tensor([[0.7495]]) tensor([[3.5702]], dtype=torch.float64)
# torch.Size([165, 512, 512])
# torch.Size([165, 512, 512])
# CHIASM tensor([[0.5093]]) tensor([[3.1055]], dtype=torch.float64)
# torch.Size([165, 512, 512])
# torch.Size([165, 512, 512])
# MAND tensor([[0.8503]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([165, 512, 512])
# torch.Size([165, 512, 512])
# LOPTIC tensor([[0.4183]]) tensor([[3.1217]], dtype=torch.float64)
# torch.Size([165, 512, 512])
# torch.Size([165, 512, 512])
# ROPTIC tensor([[0.3672]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([165, 512, 512])
# torch.Size([165, 512, 512])
# LPAR tensor([[0.8110]]) tensor([[3.6056]], dtype=torch.float64)
# torch.Size([165, 512, 512])
# torch.Size([165, 512, 512])
# RPAR tensor([[0.8161]]) tensor([[3.1623]], dtype=torch.float64)
# 4 torch.Size([1, 151, 512, 512]) torch.Size([1, 151, 512, 512])
# 19
# (1, 20, 151, 512, 512)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# BSTEM tensor([[0.7761]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# CHIASM tensor([[0.2871]]) tensor([[10.6112]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# MAND tensor([[0.7949]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# LOPTIC tensor([[0.4404]]) tensor([[6.7082]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# ROPTIC tensor([[0.4543]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# LPAR tensor([[0.8965]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# RPAR tensor([[0.8360]]) tensor([[4.1649]], dtype=torch.float64)
# 4 torch.Size([1, 146, 512, 512]) torch.Size([1, 146, 512, 512])
# 19
# (1, 20, 146, 512, 512)
# torch.Size([146, 512, 512])
# torch.Size([146, 512, 512])
# BSTEM tensor([[0.7280]]) tensor([[4.4997]], dtype=torch.float64)
# torch.Size([146, 512, 512])
# torch.Size([146, 512, 512])
# CHIASM tensor([[0.]]) tensor([[6.1644]], dtype=torch.float64)
# torch.Size([146, 512, 512])
# torch.Size([146, 512, 512])
# MAND tensor([[0.8279]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([146, 512, 512])
# torch.Size([146, 512, 512])
# LOPTIC tensor([[0.4945]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([146, 512, 512])
# torch.Size([146, 512, 512])
# ROPTIC tensor([[0.3790]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([146, 512, 512])
# torch.Size([146, 512, 512])
# LPAR tensor([[0.8679]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([146, 512, 512])
# torch.Size([146, 512, 512])
# RPAR tensor([[0.8906]]) tensor([[2.2361]], dtype=torch.float64)
# 4 torch.Size([1, 137, 512, 512]) torch.Size([1, 137, 512, 512])
# 19
# (1, 20, 137, 512, 512)
# torch.Size([137, 512, 512])
# torch.Size([137, 512, 512])
# BSTEM tensor([[0.7636]]) tensor([[3.7417]], dtype=torch.float64)
# torch.Size([137, 512, 512])
# torch.Size([137, 512, 512])
# CHIASM tensor([[0.4419]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([137, 512, 512])
# torch.Size([137, 512, 512])
# MAND tensor([[0.8527]]) tensor([[1.7321]], dtype=torch.float64)
# torch.Size([137, 512, 512])
# torch.Size([137, 512, 512])
# LOPTIC tensor([[0.4921]]) tensor([[2.4495]], dtype=torch.float64)
# torch.Size([137, 512, 512])
# torch.Size([137, 512, 512])
# ROPTIC tensor([[0.4046]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([137, 512, 512])
# torch.Size([137, 512, 512])
# LPAR tensor([[0.8540]]) tensor([[3.7417]], dtype=torch.float64)
# torch.Size([137, 512, 512])
# torch.Size([137, 512, 512])
# RPAR tensor([[0.8473]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 159, 512, 512]) torch.Size([1, 159, 512, 512])
# 19
# (1, 20, 159, 512, 512)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# BSTEM tensor([[0.8030]]) tensor([[3.4712]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# CHIASM tensor([[0.3333]]) tensor([[7.1344]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# MAND tensor([[0.8535]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# LOPTIC tensor([[0.3633]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# ROPTIC tensor([[0.4254]]) tensor([[2.5026]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# LPAR tensor([[0.8601]]) tensor([[2.8284]], dtype=torch.float64)
# torch.Size([159, 512, 512])
# torch.Size([159, 512, 512])
# RPAR tensor([[0.8361]]) tensor([[3.1623]], dtype=torch.float64)
# 4 torch.Size([1, 131, 512, 512]) torch.Size([1, 131, 512, 512])
# 19
# (1, 20, 131, 512, 512)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# BSTEM tensor([[0.7050]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# CHIASM tensor([[0.3959]]) tensor([[7.2801]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# MAND tensor([[0.8495]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# LOPTIC tensor([[0.4470]]) tensor([[4.7436]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# ROPTIC tensor([[0.4535]]) tensor([[2.4730]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# LPAR tensor([[0.8585]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# RPAR tensor([[0.8683]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 112, 512, 512]) torch.Size([1, 112, 512, 512])
# 19
# (1, 20, 112, 512, 512)
# torch.Size([109, 512, 512])
# torch.Size([109, 512, 512])
# BSTEM tensor([[0.8371]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([109, 512, 512])
# torch.Size([109, 512, 512])
# CHIASM tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([109, 512, 512])
# torch.Size([109, 512, 512])
# MAND tensor([[0.8532]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([109, 512, 512])
# torch.Size([109, 512, 512])
# LOPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([109, 512, 512])
# torch.Size([109, 512, 512])
# ROPTIC tensor([[nan]]) tensor([[nan]], dtype=torch.float64)
# torch.Size([109, 512, 512])
# torch.Size([109, 512, 512])
# LPAR tensor([[0.8625]]) tensor([[2.9571]], dtype=torch.float64)
# torch.Size([109, 512, 512])
# torch.Size([109, 512, 512])
# RPAR tensor([[0.7875]]) tensor([[3.7417]], dtype=torch.float64)
# 4 torch.Size([1, 131, 512, 512]) torch.Size([1, 131, 512, 512])
# 19
# (1, 20, 131, 512, 512)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# BSTEM tensor([[0.7266]]) tensor([[4.1231]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# CHIASM tensor([[0.2714]]) tensor([[7.6811]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# MAND tensor([[0.8263]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# LOPTIC tensor([[0.4498]]) tensor([[3.3618]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# ROPTIC tensor([[0.3827]]) tensor([[3.6374]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# LPAR tensor([[0.8102]]) tensor([[3.2163]], dtype=torch.float64)
# torch.Size([131, 512, 512])
# torch.Size([131, 512, 512])
# RPAR tensor([[0.8220]]) tensor([[3.1623]], dtype=torch.float64)
# 4 torch.Size([1, 124, 512, 512]) torch.Size([1, 124, 512, 512])
# 19
# (1, 20, 124, 512, 512)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# BSTEM tensor([[0.7385]]) tensor([[4.2426]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# CHIASM tensor([[0.2296]]) tensor([[9.4657]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# MAND tensor([[0.8124]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# LOPTIC tensor([[0.3986]]) tensor([[5.0990]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# ROPTIC tensor([[0.3321]]) tensor([[5.4259]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# LPAR tensor([[0.8355]]) tensor([[5.1962]], dtype=torch.float64)
# torch.Size([124, 512, 512])
# torch.Size([124, 512, 512])
# RPAR tensor([[0.8509]]) tensor([[3.7417]], dtype=torch.float64)
# 4 torch.Size([1, 167, 512, 512]) torch.Size([1, 167, 512, 512])
# 19
# (1, 20, 167, 512, 512)
# torch.Size([167, 512, 512])
# torch.Size([167, 512, 512])
# BSTEM tensor([[0.7492]]) tensor([[3.7417]], dtype=torch.float64)
# torch.Size([167, 512, 512])
# torch.Size([167, 512, 512])
# CHIASM tensor([[0.3253]]) tensor([[5.]], dtype=torch.float64)
# torch.Size([167, 512, 512])
# torch.Size([167, 512, 512])
# MAND tensor([[0.8185]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([167, 512, 512])
# torch.Size([167, 512, 512])
# LOPTIC tensor([[0.4639]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([167, 512, 512])
# torch.Size([167, 512, 512])
# ROPTIC tensor([[0.3492]]) tensor([[2.9450]], dtype=torch.float64)
# torch.Size([167, 512, 512])
# torch.Size([167, 512, 512])
# LPAR tensor([[0.8713]]) tensor([[3.]], dtype=torch.float64)
# torch.Size([167, 512, 512])
# torch.Size([167, 512, 512])
# RPAR tensor([[0.8563]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 151, 512, 512]) torch.Size([1, 151, 512, 512])
# 19
# (1, 20, 151, 512, 512)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# BSTEM tensor([[0.7853]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# CHIASM tensor([[0.2712]]) tensor([[6.0497]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# MAND tensor([[0.8645]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# LOPTIC tensor([[0.4392]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# ROPTIC tensor([[0.4084]]) tensor([[2.]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# LPAR tensor([[0.8709]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([151, 512, 512])
# torch.Size([151, 512, 512])
# RPAR tensor([[0.8377]]) tensor([[3.]], dtype=torch.float64)
# 4 torch.Size([1, 132, 512, 512]) torch.Size([1, 132, 512, 512])
# 19
# (1, 20, 132, 512, 512)
# torch.Size([132, 512, 512])
# torch.Size([132, 512, 512])
# BSTEM tensor([[0.7608]]) tensor([[3.1623]], dtype=torch.float64)
# torch.Size([132, 512, 512])
# torch.Size([132, 512, 512])
# CHIASM tensor([[0.2917]]) tensor([[5.8266]], dtype=torch.float64)
# torch.Size([132, 512, 512])
# torch.Size([132, 512, 512])
# MAND tensor([[0.8582]]) tensor([[1.4142]], dtype=torch.float64)
# torch.Size([132, 512, 512])
# torch.Size([132, 512, 512])
# LOPTIC tensor([[0.5035]]) tensor([[3.7076]], dtype=torch.float64)
# torch.Size([132, 512, 512])
# torch.Size([132, 512, 512])
# ROPTIC tensor([[0.3672]]) tensor([[2.2361]], dtype=torch.float64)
# torch.Size([132, 512, 512])
# torch.Size([132, 512, 512])
# LPAR tensor([[0.8540]]) tensor([[2.8284]], dtype=torch.float64)
# torch.Size([132, 512, 512])
# torch.Size([132, 512, 512])
# RPAR tensor([[0.8608]]) tensor([[2.4495]], dtype=torch.float64)

# %%
p_
# Out:
# ['0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001',
#  '0522c0001']

# %%
outputs = torch.from_numpy(np.load(out_path))

# %%
outputs.max()
# Out:
# tensor(0.)

# %%
len(oars)
# Out:
# 307

# %%
data_ = {}
data_['OAR'] = oars
data_['OAR_PDDCA'] = pddca_oars
data_['Patient'] = p_
data_['VolDice'] = dce
data_['95HD'] = hd
data_['SurfDice'] = sd
# data_['Observer'] = ob

# %%
data_ = pd.DataFrame.from_dict(data_)
data_.to_csv('/Users/joemarsilla/OARensemble2021_pddca2.csv')
data_
# data_['OAR'] = data_['OAR'].fillna("CHIASM")
# data_.to_csv('/Users/joemarsilla/OARensemble2021_pddca2.csv')
# Out:
#         OAR     OAR_PDDCA    Patient   VolDice        95HD   SurfDice
# 0     BSTEM     BrainStem  0522c0001  0.615593    5.385165   2.962209
# 1    CHIASM        Chiasm  0522c0001  0.253788    5.744563   1.998870
# 2      MAND      Mandible  0522c0001  0.773946  119.782929  10.392025
# 3    LOPTIC  OpticNerve_L  0522c0001  0.473795    1.973205   0.901536
# 4    ROPTIC  OpticNerve_R  0522c0001  0.456274    2.236068   1.027852
# ..      ...           ...        ...       ...         ...        ...
# 351    MAND      Mandible  0522c0878  0.858215    1.414214   0.641228
# 352  LOPTIC  OpticNerve_L  0522c0878  0.503497    3.707631   0.868498
# 353  ROPTIC  OpticNerve_R  0522c0878  0.367201    2.236068   1.182157
# 354    LPAR     Parotid_L  0522c0878  0.853995    2.828427   0.802964
# 355    RPAR     Parotid_R  0522c0878  0.860767    2.449490   0.870770
#
# [356 rows x 6 columns]

# %%
data_[data_['OAR'] == "CHIASM"]
# images of different sizes (sliding window must be different)
# exclude = ['0522c0727b', '0522c0727a']
# Out:
#         OAR OAR_PDDCA    Patient   VolDice       95HD  SurfDice
# 1    CHIASM    Chiasm  0522c0001  0.253788   5.744563  1.998870
# 8    CHIASM    Chiasm  0522c0001  0.253788   5.744563  1.998870
# 15   CHIASM    Chiasm  0522c0001  0.253788   5.744563  1.998870
# 22   CHIASM    Chiasm  0522c0001  0.253788   5.744563  1.998870
# 29   CHIASM    Chiasm  0522c0001  0.253788   5.744563  1.998870
# 36   CHIASM    Chiasm  0522c0002  0.372340   5.084167  1.747751
# 43   CHIASM    Chiasm  0522c0003  0.344676   4.358899  1.650466
# 50   CHIASM    Chiasm  0522c0009  0.380556   4.123106  1.553559
# 57   CHIASM    Chiasm  0522c0013  0.335766   6.324555  1.681447
# 64   CHIASM    Chiasm  0522c0014  0.341530   4.242641  1.458458
# 71   CHIASM    Chiasm  0522c0017  0.228085   6.403124  2.559960
# 78   CHIASM    Chiasm  0522c0057       NaN        NaN       NaN
# 85   CHIASM    Chiasm  0522c0070  0.262260   7.874008  2.745294
# 92   CHIASM    Chiasm  0522c0077  0.396135   8.237014  0.806824
# 99   CHIASM    Chiasm  0522c0079  0.283019   8.261101  2.436382
# 106  CHIASM    Chiasm  0522c0081  0.325163   6.403124  1.994228
# 113  CHIASM    Chiasm  0522c0125       NaN        NaN       NaN
# 120  CHIASM    Chiasm  0522c0132  0.470968   7.531857  0.791290
# 127  CHIASM    Chiasm  0522c0147  0.246835  16.522712  1.463952
# 134  CHIASM    Chiasm  0522c0149  0.288089   6.516380  0.619540
# 141  CHIASM    Chiasm  0522c0159  0.369773  10.862780  3.173825
# 148  CHIASM    Chiasm  0522c0161  0.257485   8.034020  2.432437
# 155  CHIASM    Chiasm  0522c0190  0.469673   5.477226  1.622090
# 162  CHIASM    Chiasm  0522c0195  0.241901   6.049658  1.692652
# 169  CHIASM    Chiasm  0522c0226  0.339073   7.081622  2.215532
# 176  CHIASM    Chiasm  0522c0248  0.283871   9.643651  3.124708
# 183  CHIASM    Chiasm  0522c0251       NaN        NaN       NaN
# 190  CHIASM    Chiasm  0522c0253  0.245378   9.273618  3.231193
# 197  CHIASM    Chiasm  0522c0328  0.217666  10.049876  3.229775
# 204  CHIASM    Chiasm  0522c0329  0.328657   5.099020  1.647897
# 210  CHIASM    Chiasm  0522c0330  0.081522  14.394353  5.316163
# 216  CHIASM    Chiasm  0522c0427  0.309333   9.000000  1.827206
# 222  CHIASM    Chiasm  0522c0433  0.293823   6.715617  2.414845
# 228  CHIASM    Chiasm  0522c0441  0.154303   3.605551  1.839748
# 234  CHIASM    Chiasm  0522c0455  0.373924   5.477226  1.972313
# 240  CHIASM    Chiasm  0522c0457  0.331933   5.069314  1.740901
# 246  CHIASM    Chiasm  0522c0479  0.321642   7.681146  2.330445
# 252  CHIASM    Chiasm  0522c0555  0.195950  10.515720  2.892757
# 259  CHIASM    Chiasm  0522c0576  0.307551   7.874008  2.387085
# 266  CHIASM    Chiasm  0522c0598  0.426938   6.156249  2.017676
# 273  CHIASM    Chiasm  0522c0659  0.509259   3.105480  0.925942
# 280  CHIASM    Chiasm  0522c0661  0.287081  10.611162  3.613157
# 287  CHIASM    Chiasm  0522c0667  0.000000   6.164414  1.437272
# 294  CHIASM    Chiasm  0522c0669  0.441905   3.000000  1.024401
# 301  CHIASM    Chiasm  0522c0708  0.333333   7.134392  2.479689
# 308  CHIASM    Chiasm  0522c0727  0.395939   7.280110  2.394528
# 315  CHIASM    Chiasm  0522c0746       NaN        NaN       NaN
# 322  CHIASM    Chiasm  0522c0788  0.271357   7.681146  2.623000
# 329  CHIASM    Chiasm  0522c0806  0.229630   9.465692  3.180216
# 336  CHIASM    Chiasm  0522c0845  0.325323   5.000000  1.800979
# 343  CHIASM    Chiasm  0522c0857  0.271186   6.049658  1.843169
# 350  CHIASM    Chiasm  0522c0878  0.291667   5.826632  2.129379

# %%
data_
# Out:
#         OAR     OAR_PDDCA    Patient   VolDice        95HD   SurfDice
# 0     BSTEM     BrainStem  0522c0001  0.615593    5.385165   2.962209
# 1    CHIASM        Chiasm  0522c0001  0.253788    5.744563   1.998870
# 2      MAND      Mandible  0522c0001  0.773946  119.782929  10.392025
# 3    LOPTIC  OpticNerve_L  0522c0001  0.473795    1.973205   0.901536
# 4    ROPTIC  OpticNerve_R  0522c0001  0.456274    2.236068   1.027852
# ..      ...           ...        ...       ...         ...        ...
# 351    MAND      Mandible  0522c0878  0.858215    1.414214   0.641228
# 352  LOPTIC  OpticNerve_L  0522c0878  0.503497    3.707631   0.868498
# 353  ROPTIC  OpticNerve_R  0522c0878  0.367201    2.236068   1.182157
# 354    LPAR     Parotid_L  0522c0878  0.853995    2.828427   0.802964
# 355    RPAR     Parotid_R  0522c0878  0.860767    2.449490   0.870770
#
# [356 rows x 6 columns]

# %%
# fdata = data_[~data_.Patient.isin(exclude)]
# exclude = ['Spinal-Canal']
# fdata = fdata[~fdata.OAR_Deepmind.isin(exclude)]

# %%
# fdata

# %%
import matplotlib.pyplot as plt
import seaborn as sea

# %%
# NOT CORRECTED
plt.figure(figsize=(70,40))
sea.set(font_scale=5)  # crazy big
sea.set_style("whitegrid")
sea.color_palette("Set1")
plt.title('3D Volumetric Dice (PDDCA Test Set, WOLNET)\n', fontsize=120)
rois = ['MAND', 'BSTEM', 'LPAR', 'RPAR', 'LOPTIC', 'ROPTIC', 'CHIASM']
# rois = ['MAND', 'LEYE', 'REYE', 'BSTEM', 'LARYNX', 'SPCOR', 'LPAR', 'RPAR', 'ESOPH', 'LLENS', 'RLENS', 'LACOU', 'RACOU', 'LPLEX', 'RPLEX', 'LIPS', 'LOPTIC', 'ROPTIC', 'CHIASM']
data_.OAR = data_.OAR.astype("category")
data_.OAR.cat.set_categories(rois, inplace=True)
data_.sort_values(["OAR"])
medians = data_.groupby(['OAR'])['VolDice'].median()
vertical_offset = data_['VolDice'].median() * 0.075 # offset from median for display
ax = sea.boxplot(data=data_, x="OAR", y="VolDice", hue="OAR", hue_order=rois, width=.85, linewidth=3,  dodge=False) # hue_order=chosen,
ax.set_xticklabels(rois, rotation=60, fontsize=80)
for xtick in ax.get_xticks():
    ax.text(xtick,medians[xtick] + vertical_offset, np.round(medians[xtick],2), 
            horizontalalignment='center',size='x-large',color='k',weight='semibold')
# ax.set(xlabel='\nOAR\n', ylabel='3D Volumetric Dice\n')
ax.set_xlabel('\nOAR\n', fontsize=100)
ax.set_ylabel('3D Volumetric Dice\n', fontsize=100)
# ax.legend_.remove()
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:2631: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)
# Text(0, 0.5, '3D Volumetric Dice\n')

# %%
plt.figure(figsize=(70,40))
sea.set(font_scale=5)  # crazy big
sea.set_style("whitegrid")
sea.color_palette("Set2")
plt.title('95th Percentile Hausdorff Distance (PDDCA Test Set, WOLNET)\n', fontsize=120)
ax = sea.boxplot(data=data_[data_["95HD"]<17.5], x="OAR", y="95HD", hue="OAR",hue_order=rois, width=.85, linewidth=3, dodge=False)
ax.set_xticklabels(rois, rotation=60, fontsize=80)
medians = data_.groupby(['OAR'])['95HD'].median()
vertical_offset = data_['95HD'].median() * .8 # offset from median for display
for xtick in ax.get_xticks():
    ax.text(xtick,medians[xtick] + vertical_offset, np.round(medians[xtick],2), 
            horizontalalignment='center',size='x-large',color='k',weight='semibold')
# ax.set(xlabel='\nOAR\n', ylabel='95%HD\n')
ax.set_xlabel('\nOAR\n', fontsize=100)
ax.set_ylabel('95%HD\n', fontsize=100)
# ax.legend_.remove()
# Out:
# Text(0, 0.5, '95%HD\n')
