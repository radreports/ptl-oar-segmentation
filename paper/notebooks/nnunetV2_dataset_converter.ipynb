# %%
import pandas as pd
import glob, os, numpy as np, nrrd

dataset_name = "Dataset001_HNOAR"
try:
    os.mkdir("/Users/jmarsill/Documents/nnunetV2")
    os.mkdir(f"/Users/jmarsill/Documents/nnunetV2/{dataset_name}")
    os.mkdir(f"/Users/jmarsill/Documents/nnunetV2/{dataset_name}/imagesTr")
    os.mkdir(f"/Users/jmarsill/Documents/nnunetV2/{dataset_name}/imagesTs")
    os.mkdir(f"/Users/jmarsill/Documents/nnunetV2/{dataset_name}/labelsTr")
    os.mkdir(f"/Users/jmarsill/Documents/nnunetV2/{dataset_name}/labelsTs")
except:
    pass

paths = ["/Users/jmarsill/Documents/External Data/WOLENS/Structured/DEEPMIND:PDDCA",
         "/Users/jmarsill/Documents/External Data/WOLENS/Structured/StructSeg2019",
         "/Users/jmarsill/Documents/External Data/WOLENS/Structured/TCIA-HNSCC-3DCT"]

count = 1
for p in paths:
    folders = glob.glob(p+"/*")
    for f in folders:
        patient = f.split("/")[-1]
        rois = glob.glob(f + "/structures/*")
        ending = rois[0].split(".")[-1]
        rois = [r.split("/")[-1].partition(".")[0] for r in rois]
        rois.sort()
        # read the image...its the same...
        img = nrrd.read(f+"/CT_IMAGE.nrrd")
        head = img[1]
        
        if len(str(count)) < 3:
            val_count = "0" + str(count)
            if len(val_count) < 3:
                val_count = "0" + val_count
        else:
            val_count = str(count)
                
        new_img_path = f"/Users/jmarsill/Documents/nnunetV2/{dataset_name}/imagesTr/{patient}_{val_count}_000.nrrd"
        nrrd.write(new_img_path, img[0], img[1])
        
        mask = None
        for i, roi in enumerate(rois):
            if mask is None:
                mask = nrrd.read(f + f"/structures/{roi}.{ending}")
                mask = mask[0]
            else:
                mask_ = nrrd.read(f + f"/structures/{roi}.{ending}")
                mask_ = mask_[0]
                mask[mask_==1] = i+1
        
        print(f"Finished making {mask.max()} class mask for {patient}")
        new_mask_path = f"/Users/jmarsill/Documents/nnunetV2/{dataset_name}/labelsTr/{patient}_{val_count}_000.nrrd"
        nrrd.write(new_mask_path, np.int8(mask), header=head)
        count+=1
        # break

# First set of functions recursively mine dataset in folder CT_IMAGE.nrrd structures > mask_name_0...mask_name_n
# convert to nnunetv2 dataset structure...
# for most of our cases we will be using the simple dataset structure defined in
# https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/dataset_format.md
# Here is another example of the second dataset of the MSD, which has only one input channel:
# nnUNet_raw/Dataset002_Heart/
# ├── dataset.json
# ├── imagesTr
# │   ├── la_003_0000.nii.gz
# │   ├── la_004_0000.nii.gz
# │   ├── ...
# ├── imagesTs
# │   ├── la_001_0000.nii.gz
# │   ├── la_002_0000.nii.gz
# │   ├── ...
# └── labelsTr
#     ├── la_003.nii.gz
#     ├── la_004.nii.gz
#     ├── ...

# The dataset.json contains metadata that nnU-Net needs for training. We have greatly reduced the number of required fields since version 1!
# Here is what the dataset.json should look like at the example of the Dataset005_Prostate from the MSD:
# { 
#  "channel_names": {  # formerly modalities
#    "0": "T2", 
#    "1": "ADC"
#  }, 
#  "labels": {  # THIS IS DIFFERENT NOW!
#    "background": 0,
#    "PZ": 1,
#    "TZ": 2
#  }, 
#  "numTraining": 32, 
#  "file_ending": ".nii.gz"
#  "overwrite_image_reader_writer": "SimpleITKIO"  # optional! If not provided nnU-Net will automatically determine the ReaderWriter
#  }
# Out:
# Finished making 19 class mask for TCGA-CV-5978
# Finished making 19 class mask for TCGA-CV-A6JY
# Finished making 19 class mask for TCGA-CV-5977
# Finished making 19 class mask for 0522c0708
# Finished making 19 class mask for 0522c0161
# Finished making 19 class mask for 0522c0331
# Finished making 19 class mask for 0522c0629
# Finished making 19 class mask for 0522c0479
# Finished making 19 class mask for 0522c0226
# Finished making 19 class mask for 0522c0014
# Finished making 19 class mask for 0522c0845
# Finished making 19 class mask for 0522c0659
# Finished making 19 class mask for 0522c0251
# Finished making 19 class mask for 0522c0727a
# Finished making 19 class mask for 0522c0667
# Finished making 19 class mask for 0522c0669
# Finished making 19 class mask for TCGA-CV-7236
# Finished making 19 class mask for TCGA-CV-A6K0
# Finished making 19 class mask for 0522c0770
# Finished making 19 class mask for TCGA-CV-A6K1
# Finished making 19 class mask for 0522c0519
# Finished making 19 class mask for 0522c0768
# Finished making 19 class mask for TCGA-CV-A6JO
# Finished making 19 class mask for TCGA-CV-7245
# Finished making 19 class mask for TCGA-CV-7243
# Finished making 19 class mask for 0522c0017
# Finished making 19 class mask for 0522c0427
# Finished making 19 class mask for 0522c0416
# Finished making 19 class mask for 0522c0419
# Finished making 19 class mask for 0522c0248
# Finished making 19 class mask for 0522c0727b
# Finished making 19 class mask for 0522c0457
# Finished making 19 class mask for 0522c0057
# Finished making 19 class mask for 0522c0773
# Finished making 19 class mask for 0522c0576
# Finished making 19 class mask for 50
# Finished making 19 class mask for 32
# Finished making 19 class mask for 35
# Finished making 19 class mask for 34
# Finished making 19 class mask for 33
# Finished making 19 class mask for 20
# Finished making 19 class mask for 18
# Finished making 19 class mask for 27
# Finished making 19 class mask for 9
# Finished making 19 class mask for 11
# Finished making 19 class mask for 7
# Finished making 19 class mask for 29
# Finished making 19 class mask for 16
# Finished making 19 class mask for 42
# Finished making 19 class mask for 45
# Finished making 19 class mask for 6
# Finished making 19 class mask for 28
# Finished making 19 class mask for 17
# Finished making 19 class mask for 1
# Finished making 19 class mask for 10
# Finished making 19 class mask for 19
# Finished making 19 class mask for 26
# Finished making 19 class mask for 8
# Finished making 19 class mask for 21
# Finished making 19 class mask for 44
# Finished making 19 class mask for 43
# Finished making 19 class mask for 38
# Finished making 19 class mask for 36
# Finished making 19 class mask for 31
# Finished making 19 class mask for 30
# Finished making 19 class mask for 37
# Finished making 19 class mask for 39
# Finished making 19 class mask for 46
# Finished making 19 class mask for 41
# Finished making 19 class mask for 48
# Finished making 19 class mask for 24
# Finished making 19 class mask for 23
# Finished making 19 class mask for 4
# Finished making 19 class mask for 15
# Finished making 19 class mask for 3
# Finished making 19 class mask for 12
# Finished making 19 class mask for 49
# Finished making 19 class mask for 40
# Finished making 19 class mask for 47
# Finished making 19 class mask for 2
# Finished making 19 class mask for 13
# Finished making 19 class mask for 5
# Finished making 19 class mask for 14
# Finished making 19 class mask for 22
# Finished making 19 class mask for 25
# Finished making 19 class mask for HN_P018_0
# Finished making 19 class mask for HN_P033_1
# Finished making 19 class mask for HN_P012_0
# Finished making 19 class mask for HN_P014_2
# Finished making 19 class mask for HN_P016_1
# Finished making 19 class mask for HN_P033_0
# Finished making 19 class mask for HN_P012_1
# Finished making 19 class mask for HN_P018_1
# Finished making 19 class mask for HN_P010_2
# Finished making 19 class mask for HN_P016_0
# Finished making 19 class mask for HN_P023_0
# Finished making 19 class mask for HN_P002_1
# Finished making 19 class mask for HN_P008_1
# Finished making 19 class mask for HN_P029_0
# Finished making 19 class mask for HN_P027_1
# Finished making 19 class mask for HN_P008_0
# Finished making 19 class mask for HN_P029_1
# Finished making 19 class mask for HN_P023_1
# Finished making 19 class mask for HN_P002_0
# Finished making 19 class mask for HN_P004_2
# Finished making 19 class mask for HN_P027_0
# Finished making 19 class mask for HN_P017_2
# Finished making 19 class mask for HN_P034_0
# Finished making 19 class mask for HN_P015_1
# Finished making 19 class mask for HN_P011_0
# Finished making 19 class mask for HN_P030_1
# Finished making 19 class mask for HN_P034_1
# Finished making 19 class mask for HN_P015_0
# Finished making 19 class mask for HN_P011_1
# Finished making 19 class mask for HN_P030_0
# Finished making 19 class mask for HN_P019_2
# Finished making 19 class mask for HN_P013_2
# Finished making 19 class mask for HN_P024_1
# Finished making 19 class mask for HN_P005_0
# Finished making 19 class mask for HN_P026_2
# Finished making 19 class mask for HN_P001_1
# Finished making 19 class mask for HN_P009_2
# Finished making 19 class mask for HN_P003_2
# Finished making 19 class mask for HN_P007_2
# Finished making 19 class mask for HN_P024_0
# Finished making 19 class mask for HN_P005_1
# Finished making 19 class mask for HN_P022_2
# Finished making 19 class mask for HN_P001_0
# Finished making 19 class mask for HN_P020_1
# Finished making 19 class mask for HN_P028_2
# Finished making 19 class mask for HN_P014_1
# Finished making 19 class mask for HN_P016_2
# Finished making 19 class mask for HN_P010_0
# Finished making 19 class mask for HN_P033_2
# Finished making 19 class mask for HN_P014_0
# Finished making 19 class mask for HN_P012_2
# Finished making 19 class mask for HN_P018_2
# Finished making 19 class mask for HN_P010_1
# Finished making 19 class mask for HN_P027_2
# Finished making 19 class mask for HN_P004_0
# Finished making 19 class mask for HN_P002_2
# Finished making 19 class mask for HN_P008_2
# Finished making 19 class mask for HN_P004_1
# Finished making 19 class mask for HN_P029_2
# Finished making 19 class mask for HN_P023_2
# Finished making 19 class mask for HN_P013_0
# Finished making 19 class mask for HN_P032_1
# Finished making 19 class mask for HN_P030_2
# Finished making 19 class mask for HN_P019_0
# Finished making 19 class mask for HN_P017_1
# Finished making 19 class mask for HN_P015_2
# Finished making 19 class mask for HN_P011_2
# Finished making 19 class mask for HN_P019_1
# Finished making 19 class mask for HN_P013_1
# Finished making 19 class mask for HN_P034_2
# Finished making 19 class mask for HN_P017_0
# Finished making 19 class mask for HN_P001_2
# Finished making 19 class mask for HN_P028_0
# Finished making 19 class mask for HN_P009_1
# Finished making 19 class mask for HN_P022_0
# Finished making 19 class mask for HN_P024_2
# Finished making 19 class mask for HN_P026_1
# Finished making 19 class mask for HN_P007_0
# Finished making 19 class mask for HN_P022_1
# Finished making 19 class mask for HN_P028_1
# Finished making 19 class mask for HN_P009_0
# Finished making 19 class mask for HN_P026_0
# Finished making 19 class mask for HN_P007_1
# Finished making 19 class mask for HN_P005_2

# %%
im = glob.glob("/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/*")

# %%
im = [i for i in im if "099" in i]

# %%
len(im)
# Out:
# 71

# %%
im_ = [i.replace("099",str(100+c)) for c, i in enumerate(im)]

# %%
im_
# Out:
# ['/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P020_1_100_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P026_0_101_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P015_2_102_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P008_2_103_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P028_1_104_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P034_0_105_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P032_1_106_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P027_1_107_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P012_2_108_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P007_2_109_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P029_0_110_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P028_0_111_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P026_1_112_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P013_2_113_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P009_2_114_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P029_1_115_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P027_0_116_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P034_1_117_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P001_2_118_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P016_2_119_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P003_2_120_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P023_1_121_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P030_0_122_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P019_2_123_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P004_2_124_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P011_2_125_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P022_0_126_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P024_1_127_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P005_2_128_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P030_1_129_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P018_2_130_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P002_2_131_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P017_2_132_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P024_0_133_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P022_1_134_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P023_2_135_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P005_0_136_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P010_0_137_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P024_2_138_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P017_0_139_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P002_0_140_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P004_1_141_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P011_1_142_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P019_1_143_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P030_2_144_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P010_1_145_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P005_1_146_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P019_0_147_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P022_2_148_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P011_0_149_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P004_0_150_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P017_1_151_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P028_2_152_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P015_1_153_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P013_0_154_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P009_0_155_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P001_0_156_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P014_0_157_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P007_1_158_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P027_2_159_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P013_1_160_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P015_0_161_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P026_2_162_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P033_2_163_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P008_0_164_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P007_0_165_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P014_1_166_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P001_1_167_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P034_2_168_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P029_2_169_000.nrrd',
#  '/Users/jmarsill/Documents/nnunetV2/Dataset001_HNOAR/imagesTr/HN_P009_1_170_000.nrrd']

# %%
import shutil
for i, v in enumerate(im):
    shutil.move(v.replace("imagesTr","labelsTr"), im_[i].replace("imagesTr","labelsTr"))
